# %% [markdown]
# # ANN (Iris Dataset + Graphs)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras

# %%
data = load_iris()
X = data.data
y = data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model_ann = keras.Sequential([
    keras.layers.Dense(16, activation='relu', input_shape=(4,)),
    keras.layers.Dense(8, activation='relu'),
    keras.layers.Dense(3, activation='softmax')
])

model_ann.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

# %%
history_ann = model_ann.fit(
    X_train, y_train,
    epochs=20,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 145ms/step - accuracy: 0.1250 - loss: 1.0981 - val_accuracy: 0.3000 - val_loss: 1.0952
# Epoch 2/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.1833 - loss: 1.0880 - val_accuracy: 0.3333 - val_loss: 1.0915
# Epoch 3/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.2250 - loss: 1.0787 - val_accuracy: 0.4000 - val_loss: 1.0887
# Epoch 4/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2583 - loss: 1.0699 - val_accuracy: 0.4000 - val_loss: 1.0860
# Epoch 5/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.2750 - loss: 1.0615 - val_accuracy: 0.4000 - val_loss: 1.0834
# Epoch 6/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2917 - loss: 1.0527 - val_accuracy: 0.4333 - val_loss: 1.0809
# Epoch 7/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.2917 - loss: 1.0439 - val_accuracy: 0.4667 - val_loss: 1.0784
# Epoch 8/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.3000 - loss: 1.0345 - val_accuracy: 0.4667 - val_loss: 1.0757
# Epoch 9/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.3583 - loss: 1.0256 - val_accuracy: 0.5667 - val_loss: 1.0731
# Epoch 10/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5583 - loss: 1.0156 - val_accuracy: 0.6000 - val_loss: 1.0705
# Epoch 11/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6333 - loss: 1.0052 - val_accuracy: 0.6000 - val_loss: 1.0675
# Epoch 12/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6333 - loss: 0.9947 - val_accuracy: 0.6000 - val_loss: 1.0642
# Epoch 13/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6417 - loss: 0.9835 - val_accuracy: 0.5333 - val_loss: 1.0606
# Epoch 14/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6667 - loss: 0.9714 - val_accuracy: 0.5333 - val_loss: 1.0564
# Epoch 15/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6667 - loss: 0.9587 - val_accuracy: 0.5333 - val_loss: 1.0519
# Epoch 16/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6667 - loss: 0.9471 - val_accuracy: 0.5333 - val_loss: 1.0471
# Epoch 17/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6667 - loss: 0.9332 - val_accuracy: 0.5333 - val_loss: 1.0420
# Epoch 18/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6667 - loss: 0.9203 - val_accuracy: 0.5333 - val_loss: 1.0367
# Epoch 19/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6750 - loss: 0.9058 - val_accuracy: 0.5333 - val_loss: 1.0311
# Epoch 20/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6750 - loss: 0.8923 - val_accuracy: 0.5000 - val_loss: 1.0252

# %%
# Accuracy graph
plt.figure()
plt.plot(history_ann.history['accuracy'])
plt.plot(history_ann.history['val_accuracy'])
plt.title("ANN Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Train", "Validation"])
plt.show()

# Loss graph
plt.figure()
plt.plot(history_ann.history['loss'])
plt.plot(history_ann.history['val_loss'])
plt.title("ANN Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Train", "Validation"])
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_pred = model_ann.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.title("ANN Confusion Matrix")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step

# %% [markdown]
# # CNN (MNIST + Visualization)

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
plt.figure()
for i in range(6):
    plt.subplot(2,3,i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.title(f"Label: {y_train[i]}")
    plt.axis('off')
plt.show()

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

X_train = X_train.reshape(-1,28,28,1)
X_test = X_test.reshape(-1,28,28,1)

# %%
model_cnn = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(28,28,1)), # Explicitly define Input layer
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model_cnn.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history_cnn = model_cnn.fit(
    X_train, y_train,
    epochs=5,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 59s 30ms/step - accuracy: 0.9575 - loss: 0.1413 - val_accuracy: 0.9803 - val_loss: 0.0605
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 79s 29ms/step - accuracy: 0.9848 - loss: 0.0487 - val_accuracy: 0.9865 - val_loss: 0.0439
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - accuracy: 0.9890 - loss: 0.0336 - val_accuracy: 0.9913 - val_loss: 0.0267
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 84s 30ms/step - accuracy: 0.9921 - loss: 0.0245 - val_accuracy: 0.9887 - val_loss: 0.0357
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 82s 30ms/step - accuracy: 0.9946 - loss: 0.0182 - val_accuracy: 0.9916 - val_loss: 0.0278

# %%
# Accuracy
plt.figure()
plt.plot(history_cnn.history['accuracy'])
plt.plot(history_cnn.history['val_accuracy'])
plt.title("CNN Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Train", "Validation"])
plt.show()

# Loss
plt.figure()
plt.plot(history_cnn.history['loss'])
plt.plot(history_cnn.history['val_loss'])
plt.title("CNN Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Train", "Validation"])
plt.show()

# %%
predictions = model_cnn.predict(X_test)

plt.figure()
for i in range(6):
    plt.subplot(2,3,i+1)
    plt.imshow(X_test[i].reshape(28,28), cmap='gray')
    plt.title(f"Pred: {np.argmax(predictions[i])}")
    plt.axis('off')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step
